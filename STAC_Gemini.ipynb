# %% [markdown]
# <a href="https://colab.research.google.com/github/milver/Experiments/blob/main/STAC_Gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install jupyter-ai langchain_google_genai
# %pip install langchain_nvidia_ai_endpoints

# %%
# %load_ext jupyter_ai

# %%
import os
from google.colab import userdata

# %%
os.environ['GOOGLE_API_KEY'] = userdata.get('GOOGLE_API_KEY')

# %%
# %ai list
# Out:
# ai21
# Requires environment variable: AI21_API_KEY (not set)
# * ai21:j1-large
# * ai21:j1-grande
# * ai21:j1-jumbo
# * ai21:j1-grande-instruct
# * ai21:j2-large
# * ai21:j2-grande
# * ai21:j2-jumbo
# * ai21:j2-grande-instruct
# * ai21:j2-jumbo-instruct
#
# bedrock
# * bedrock:amazon.titan-text-express-v1
# * bedrock:ai21.j2-ultra-v1
# * bedrock:ai21.j2-mid-v1
# * bedrock:cohere.command-light-text-v14
# * bedrock:cohere.command-text-v14
# * bedrock:meta.llama2-13b-chat-v1
# * bedrock:meta.llama2-70b-chat-v1
#
# bedrock-chat
# * bedrock-chat:anthropic.claude-v2
# * bedrock-chat:anthropic.claude-v2:1
# * bedrock-chat:anthropic.claude-instant-v1
# * bedrock-chat:anthropic.claude-3-sonnet-20240229-v1:0
#
# anthropic
# Requires environment variable: ANTHROPIC_API_KEY (not set)
# * anthropic:claude-v1
# * anthropic:claude-v1.0
# * anthropic:claude-v1.2
# * anthropic:claude-2
# * anthropic:claude-2.0
# * anthropic:claude-instant-v1
# * anthropic:claude-instant-v1.0
# * anthropic:claude-instant-v1.2
#
# anthropic-chat
# Requires environment variable: ANTHROPIC_API_KEY (not set)
# * anthropic-chat:claude-2.0
# * anthropic-chat:claude-2.1
# * anthropic-chat:claude-instant-1.2
# * anthropic-chat:claude-3-opus-20240229
# * anthropic-chat:claude-3-sonnet-20240229
#
# azure-chat-openai
# Requires environment variable: OPENAI_API_KEY (not set)
# * This provider does not define a list of models.
#
# cohere
# Requires environment variable: COHERE_API_KEY (not set)
# * cohere:command
# * cohere:command-nightly
# * cohere:command-light
# * cohere:command-light-nightly
#
# gemini
# Requires environment variable: GOOGLE_API_KEY (set)
# * gemini:gemini-1.0-pro
# * gemini:gemini-1.0-pro-001
# * gemini:gemini-1.0-pro-latest
# * gemini:gemini-1.0-pro-vision-latest
# * gemini:gemini-pro
# * gemini:gemini-pro-vision
#
# gpt4all
# * gpt4all:ggml-gpt4all-j-v1.2-jazzy
# * gpt4all:ggml-gpt4all-j-v1.3-groovy
# * gpt4all:ggml-gpt4all-l13b-snoozy
# * gpt4all:mistral-7b-openorca.Q4_0
# * gpt4all:mistral-7b-instruct-v0.1.Q4_0
# * gpt4all:gpt4all-falcon-q4_0
# * gpt4all:wizardlm-13b-v1.2.Q4_0
# * gpt4all:nous-hermes-llama2-13b.Q4_0
# * gpt4all:gpt4all-13b-snoozy-q4_0
# * gpt4all:mpt-7b-chat-merges-q4_0
# * gpt4all:orca-mini-3b-gguf2-q4_0
# * gpt4all:starcoder-q4_0
# * gpt4all:rift-coder-v0-7b-q4_0
# * gpt4all:em_german_mistral_v01.Q4_0
#
# huggingface_hub
# Requires environment variable: HUGGINGFACEHUB_API_TOKEN (not set)
# * See [https://huggingface.co/models](https://huggingface.co/models) for a list of models. Pass a model's repository ID as the model ID; for example, `huggingface_hub:ExampleOwner/example-model`.
#
# nvidia-chat
# Requires environment variable: NVIDIA_API_KEY (not set)
# * nvidia-chat:playground_llama2_70b
# * nvidia-chat:playground_nemotron_steerlm_8b
# * nvidia-chat:playground_mistral_7b
# * nvidia-chat:playground_nv_llama2_rlhf_70b
# * nvidia-chat:playground_llama2_13b
# * nvidia-chat:playground_steerlm_llama_70b
# * nvidia-chat:playground_llama2_code_13b
# * nvidia-chat:playground_yi_34b
# * nvidia-chat:playground_mixtral_8x7b
# * nvidia-chat:playground_neva_22b
# * nvidia-chat:playground_llama2_code_34b
#
# openai
# Requires environment variable: OPENAI_API_KEY (not set)
# * openai:babbage-002
# * openai:davinci-002
# * openai:gpt-3.5-turbo-instruct
#
# openai-chat
# Requires environment variable: OPENAI_API_KEY (not set)
# * openai-chat:gpt-3.5-turbo
# * openai-chat:gpt-3.5-turbo-0125
# * openai-chat:gpt-3.5-turbo-0301
# * openai-chat:gpt-3.5-turbo-0613
# * openai-chat:gpt-3.5-turbo-1106
# * openai-chat:gpt-3.5-turbo-16k
# * openai-chat:gpt-3.5-turbo-16k-0613
# * openai-chat:gpt-4
# * openai-chat:gpt-4-turbo-preview
# * openai-chat:gpt-4-0613
# * openai-chat:gpt-4-32k
# * openai-chat:gpt-4-32k-0613
# * openai-chat:gpt-4-0125-preview
# * openai-chat:gpt-4-1106-preview
#
# qianfan
# Requires environment variables: QIANFAN_AK (not set), QIANFAN_SK (not set)
# * qianfan:ERNIE-Bot
# * qianfan:ERNIE-Bot-4
#
# sagemaker-endpoint
# * Specify an endpoint name as the model ID. In addition, you must specify a region name, request schema, and response path. For more information, see the documentation about [SageMaker endpoints deployment](https://docs.aws.amazon.com/sagemaker/latest/dg/realtime-endpoints-deployment.html) and about [using magic commands with SageMaker endpoints](https://jupyter-ai.readthedocs.io/en/latest/users/index.html#using-magic-commands-with-sagemaker-endpoints).
#
# togetherai
# Requires environment variable: TOGETHER_API_KEY (not set)
# * togetherai:Austism/chronos-hermes-13b
# * togetherai:DiscoResearch/DiscoLM-mixtral-8x7b-v2
# * togetherai:EleutherAI/llemma_7b
# * togetherai:Gryphe/MythoMax-L2-13b
# * togetherai:Meta-Llama/Llama-Guard-7b
# * togetherai:Nexusflow/NexusRaven-V2-13B
# * togetherai:NousResearch/Nous-Capybara-7B-V1p9
# * togetherai:NousResearch/Nous-Hermes-2-Yi-34B
# * togetherai:NousResearch/Nous-Hermes-Llama2-13b
# * togetherai:NousResearch/Nous-Hermes-Llama2-70b
#
#
# Aliases and custom commands:
# gpt2 - huggingface_hub:gpt2
# gpt3 - openai:davinci-002
# chatgpt - openai-chat:gpt-3.5-turbo
# gpt4 - openai-chat:gpt-4
# ernie-bot - qianfan:ERNIE-Bot
# ernie-bot-4 - qianfan:ERNIE-Bot-4
# titan - bedrock:amazon.titan-tg1-large

# %%
#%pip install leafmap
#%pip install pystac
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Requirement already satisfied: pystac in /usr/local/lib/python3.10/dist-packages (1.9.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from pystac) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7.0->pystac) (1.16.0)

# %%
import leafmap
m = leafmap.Map(center=[39.04446940931973, -77.45992183685304], zoom = 16, basemap = "Google Maps")
m
# Out:
# Map(center=[39.04446940931973, -77.45992183685304], controls=(ZoomControl(options=['position', 'zoom_in_text',…

# %%
bbox1 = [m.west, m.south, m.east, m.north]
print("{}: {}".format(m.center, m.zoom))
# Out:
# [39.04446940931973, -77.45992183685304]: 16.0

# %%
from pystac_client import Client

# set pystac_client logger to DEBUG to see API calls
# import logging
# logging.basicConfig()
# logger = logging.getLogger('pystac_client')
# logger.setLevel(logging.DEBUG)

# %%
# STAC API root URL
URL = 'https://planetarycomputer.microsoft.com/api/stac/v1'

# custom headers
headers = []

cat = Client.open(URL, headers=headers)
cat
# Out:
# <Client id=microsoft-pc>

# %%
# prompt: I want a drop-down box that has a list of all of the collections in the catalog. Once a collection has been selected, assign the collection id to a variable called MyCollection

import ipywidgets as widgets

# Get a list of all collections in the catalog
collections = cat.get_collections()

# Create a dropdown widget
dropdown = widgets.Dropdown(
    options=[c.id for c in collections],
    description='Collection:',
    disabled=False,
)

# Display the dropdown widget
display(dropdown)

# Define a function to handle the selection event
def on_change(change):
    global MyCollection
    MyCollection = change['new']

# Register the function to be called when the selection changes
dropdown.observe(on_change, names='value')
# Out:
# Dropdown(description='Collection:', options=('daymet-annual-pr', 'daymet-daily-hi', '3dep-seamless', '3dep-lid…

# %%
# limit sets the # of items per page so we can see multiple pages getting fetched
search = cat.search(
    max_items = 50,
    collections = MyCollection,
    #intersects = geom,
    bbox = bbox1,
    #datetime = "2015-01-01/2024-03-31",
)
# retrieve the items as dictionaries, rather than Item objects
items = list(search.items_as_dicts())
len(items)
# Out:
# 3

# %%
for item in search.items():
    print(f"- {item.id}")
# Out:
# - USGS_LPC_VA_Fairfax_County_2018-dtm-2m-1-0
# - VA_LoudounCo_2012-dtm-2m-5-4
# - VA_LoudounCo_2012-dtm-2m-5-3

# %%
# prompt: modify the previous cell code to print the item id and the respective asset key values, like "thumbnail"

# Print the item ID and the respective asset key values
for item in search.items():
    print(f"{item.id}:")
    for key, value in item.assets.items():
        print(f"  {key}: {value}")
# Out:
# USGS_LPC_VA_Fairfax_County_2018-dtm-2m-1-0:
#   data: <Asset href=https://usgslidareuwest.blob.core.windows.net/usgs-3dep-cogs/usgs-cogs/USGS_LPC_VA_Fairfax_County_2018/dtm/USGS_LPC_VA_Fairfax_County_2018-dtm-2m-1-0.tif>
#   thumbnail: <Asset href=https://usgslidareuwest.blob.core.windows.net/usgs-3dep-cogs/usgs-cogs/USGS_LPC_VA_Fairfax_County_2018/dtm/thumbnails/USGS_LPC_VA_Fairfax_County_2018-dtm-2m-1-0-thumbnail.png>
#   tilejson: <Asset href=https://planetarycomputer.microsoft.com/api/data/v1/item/tilejson.json?collection=3dep-lidar-dtm&item=USGS_LPC_VA_Fairfax_County_2018-dtm-2m-1-0&assets=data&nodata=-9999&format=png>
#   rendered_preview: <Asset href=https://planetarycomputer.microsoft.com/api/data/v1/item/preview.png?collection=3dep-lidar-dtm&item=USGS_LPC_VA_Fairfax_County_2018-dtm-2m-1-0&assets=data&nodata=-9999&format=png>
# VA_LoudounCo_2012-dtm-2m-5-4:
#   data: <Asset href=https://usgslidareuwest.blob.core.windows.net/usgs-3dep-cogs/usgs-cogs/VA_LoudounCo_2012/dtm/VA_LoudounCo_2012-dtm-2m-5-4.tif>
#   thumbnail: <Asset href=https://usgslidareuwest.blob.core.windows.net/usgs-3dep-cogs/usgs-cogs/VA_LoudounCo_2012/dtm/thumbnails/VA_LoudounCo_2012-dtm-2m-5-4-thumbnail.png>
#   tilejson: <Asset href=https://planetarycomputer.microsoft.com/api/data/v1/item/tilejson.json?collection=3dep-lidar-dtm&item=VA_LoudounCo_2012-dtm-2m-5-4&assets=data&nodata=-9999&format=png>
#   rendered_preview: <Asset href=https://planetarycomputer.microsoft.com/api/data/v1/item/preview.png?collection=3dep-lidar-dtm&item=VA_LoudounCo_2012-dtm-2m-5-4&assets=data&nodata=-9999&format=png>
# VA_LoudounCo_2012-dtm-2m-5-3:
#   data: <Asset href=https://usgslidareuwest.blob.core.windows.net/usgs-3dep-cogs/usgs-cogs/VA_LoudounCo_2012/dtm/VA_LoudounCo_2012-dtm-2m-5-3.tif>
#   thumbnail: <Asset href=https://usgslidareuwest.blob.core.windows.net/usgs-3dep-cogs/usgs-cogs/VA_LoudounCo_2012/dtm/thumbnails/VA_LoudounCo_2012-dtm-2m-5-3-thumbnail.png>
#   tilejson: <Asset href=https://planetarycomputer.microsoft.com/api/data/v1/item/tilejson.json?collection=3dep-lidar-dtm&item=VA_LoudounCo_2012-dtm-2m-5-3&assets=data&nodata=-9999&format=png>
#   rendered_preview: <Asset href=https://planetarycomputer.microsoft.com/api/data/v1/item/preview.png?collection=3dep-lidar-dtm&item=VA_LoudounCo_2012-dtm-2m-5-3&assets=data&nodata=-9999&format=png>

# %%
# prompt: add the tilejson assets to the leafmap and display them. Alert when the assets are loaded.

import leafmap
m = leafmap.Map(center=[39.04446940931973, -77.45992183685304], zoom = 16, basemap = "Google Maps")

# Get the tilejson asset from the first item in the search results
tilejson_asset = items[0]['assets']['tilejson']

# Add the tilejson asset to the map

m.add_tile_layer(tilejson_asset['href'], name='dem1', attribution='Microsoft Planetary Computer')

# Display the map
m

# Alert when the tilejson layer is loaded
#m.on_add_layer(lambda layer: print(f"TileJSON layer '{layer.name}' loaded."))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[39.04446940931973, -77.45992183685304], controls=(ZoomControl(options=['position', 'zoom_in_text',…

# %%
# PROJECT = 'ee-my-milver'
# !gcloud auth login --project {PROJECT}
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Go to the following link in your browser:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=32555940559.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fsdk.cloud.google.com%2Fauthcode.html&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth&state=CNBXtsEq3Xdyi6WO9wyInR924sSTYp&prompt=consent&token_usage=remote&access_type=offline&code_challenge=ZW4JKfuFpO0Ra1jwk1srLdQB68w6FWAfMLvCpaMEsdE&code_challenge_method=S256
#
# Enter authorization code: 4/0AeaYSHD9_YDG3MyaRmxEDfZ6yAv3qRqM4p2rznDDV5AazfECUrKZHilA8Acq9fW6e3fTbQ
#
# You are now logged in as [valenzuela2003@gmail.com].
# Your current project is [ee-my-milver].  You can change this setting by running:
#   $ gcloud config set project PROJECT_ID

# %%
# prompt: Create a geemap instance and add the tilejson_asset that was referenced in the previous cell, to the map
import ee
import geemap

ee.Authenticate()
ee.Initialize(project = 'ee-my-milver')

# Create a geemap instance
map = geemap.Map()

# Add the tilejson asset to the map
map.add_tile_layer(tilejson_asset['href'], name='dem1', attribution='Microsoft Planetary Computer')

map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %%
# %%ai gemini-pro -f text
#
# Create a geemap instance and add the tilejson_asset that was referenced in the previous cell, to the map
# Out:
# ```
# import ee
# from geemap import geemap
#
# # Create a geemap instance
# Map = geemap.Map()
#
# # Add the tilejson_asset to the map
# Map.add_tilelayer(tilejson_asset, {}, 'my_tile_layer')
#
# # Display the map
# Map
# ```

# %%
import ee
import geemap

# Create a map centered at (lat, lon).
map = geemap.Map(center=[40, -100], zoom=4)

# Load an Earth Engine image.
image = ee.Image('srtm90_v4')

# Add the image to the map.
map.addLayer(image, {'min': 0, 'max': 3000}, 'SRTM')

# Display the map.
map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[40, -100], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(ch…
