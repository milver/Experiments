# %% [markdown]
# <a href="https://colab.research.google.com/github/milver/Experiments/blob/main/STAC_Gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install jupyter-ai langchain_google_genai
# %pip install langchain_nvidia_ai_endpoints
# Out:
# Collecting jupyter-ai
#   Downloading jupyter_ai-2.12.0-py3-none-any.whl (929 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 929.3/929.3 kB 8.9 MB/s eta 0:00:00
# Collecting langchain_google_genai
#   Downloading langchain_google_genai-0.0.11-py3-none-any.whl (28 kB)
# Collecting aiosqlite>=0.18 (from jupyter-ai)
#   Downloading aiosqlite-0.20.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: dask[distributed] in /usr/local/lib/python3.10/dist-packages (from jupyter-ai) (2023.8.1)
# Collecting deepmerge>=1.0 (from jupyter-ai)
#   Downloading deepmerge-1.1.1-py3-none-any.whl (8.6 kB)
# Collecting faiss-cpu (from jupyter-ai)
#   Downloading faiss_cpu-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 21.4 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-ai) (7.0.2)
# Collecting jupyter-ai-magics (from jupyter-ai)
#   Downloading jupyter_ai_magics-2.12.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: jupyter-server<3,>=1.6 in /usr/local/lib/python3.10/dist-packages (from jupyter-ai) (1.24.0)
# Collecting jupyterlab~=4.0 (from jupyter-ai)
#   Downloading jupyterlab-4.1.5-py3-none-any.whl (11.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 41.2 MB/s eta 0:00:00
# Collecting tiktoken (from jupyter-ai)
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 22.0 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>=5.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-ai) (5.7.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-ai) (4.10.0)
# Collecting google-generativeai<0.5.0,>=0.4.1 (from langchain_google_genai)
#   Downloading google_generativeai-0.4.1-py3-none-any.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.4/137.4 kB 11.5 MB/s eta 0:00:00
# Collecting langchain-core<0.2,>=0.1 (from langchain_google_genai)
#   Downloading langchain_core-0.1.32-py3-none-any.whl (260 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.9/260.9 kB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: google-ai-generativelanguage==0.4.0 in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.5.0,>=0.4.1->langchain_google_genai) (0.4.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.5.0,>=0.4.1->langchain_google_genai) (2.27.0)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.5.0,>=0.4.1->langchain_google_genai) (2.11.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.5.0,>=0.4.1->langchain_google_genai) (3.20.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.5.0,>=0.4.1->langchain_google_genai) (2.6.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from google-generativeai<0.5.0,>=0.4.1->langchain_google_genai) (4.66.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.4.0->google-generativeai<0.5.0,>=0.4.1->langchain_google_genai) (1.23.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=5.2.0->jupyter-ai) (3.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.6->jupyter-ai) (3.7.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.6->jupyter-ai) (23.1.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.6->jupyter-ai) (3.1.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.6->jupyter-ai) (6.1.12)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.6->jupyter-ai) (5.7.2)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.6->jupyter-ai) (6.5.4)
# Requirement already satisfied: nbformat>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.6->jupyter-ai) (5.10.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.6->jupyter-ai) (24.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.6->jupyter-ai) (0.20.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.6->jupyter-ai) (23.2.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.6->jupyter-ai) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.6->jupyter-ai) (0.18.1)
# Requirement already satisfied: tornado>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.6->jupyter-ai) (6.3.3)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.6->jupyter-ai) (1.7.0)
# Collecting async-lru>=1.0.0 (from jupyterlab~=4.0->jupyter-ai)
#   Downloading async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Collecting httpx>=0.25.0 (from jupyterlab~=4.0->jupyter-ai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from jupyterlab~=4.0->jupyter-ai) (5.5.6)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab~=4.0->jupyter-ai)
#   Downloading jupyter_lsp-2.2.4-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 5.7 MB/s eta 0:00:00
# Collecting jupyter-server<3,>=1.6 (from jupyter-ai)
#   Downloading jupyter_server-2.13.0-py3-none-any.whl (383 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.2/383.2 kB 8.9 MB/s eta 0:00:00
# Collecting jupyterlab-server<3,>=2.19.0 (from jupyterlab~=4.0->jupyter-ai)
#   Downloading jupyterlab_server-2.25.4-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.10/dist-packages (from jupyterlab~=4.0->jupyter-ai) (0.2.4)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from jupyterlab~=4.0->jupyter-ai) (2.0.1)
# Collecting jupyter-client>=7.4.4 (from jupyter-server<3,>=1.6->jupyter-ai)
#   Downloading jupyter_client-8.6.1-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.9/105.9 kB 6.5 MB/s eta 0:00:00
# Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=1.6->jupyter-ai)
#   Downloading jupyter_events-0.10.0-py3-none-any.whl (18 kB)
# Collecting jupyter-server-terminals (from jupyter-server<3,>=1.6->jupyter-ai)
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Collecting overrides (from jupyter-server<3,>=1.6->jupyter-ai)
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting pyzmq>=24 (from jupyter-server<3,>=1.6->jupyter-ai)
#   Downloading pyzmq-25.1.2-cp310-cp310-manylinux_2_28_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2,>=0.1->langchain_google_genai) (6.0.1)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.2,>=0.1->langchain_google_genai)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langsmith<0.2.0,>=0.1.0 (from langchain-core<0.2,>=0.1->langchain_google_genai)
#   Downloading langsmith-0.1.29-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.9/70.9 kB 2.9 MB/s eta 0:00:00
# Collecting packaging (from jupyterlab~=4.0->jupyter-ai)
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2,>=0.1->langchain_google_genai) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2,>=0.1->langchain_google_genai) (8.2.3)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask[distributed]->jupyter-ai) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask[distributed]->jupyter-ai) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask[distributed]->jupyter-ai) (2023.6.0)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask[distributed]->jupyter-ai) (1.4.1)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask[distributed]->jupyter-ai) (0.12.1)
# Requirement already satisfied: distributed==2023.8.1 in /usr/local/lib/python3.10/dist-packages (from dask[distributed]->jupyter-ai) (2023.8.1)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask[distributed]->jupyter-ai) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask[distributed]->jupyter-ai) (1.0.8)
# Requirement already satisfied: psutil>=5.7.2 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask[distributed]->jupyter-ai) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask[distributed]->jupyter-ai) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask[distributed]->jupyter-ai) (3.0.0)
# Requirement already satisfied: urllib3>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask[distributed]->jupyter-ai) (2.0.7)
# Requirement already satisfied: zict>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask[distributed]->jupyter-ai) (3.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from faiss-cpu->jupyter-ai) (1.25.2)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from jupyter-ai-magics->jupyter-ai) (7.34.0)
# Collecting jsonpath-ng<2,>=1.5.3 (from jupyter-ai-magics->jupyter-ai)
#   Downloading jsonpath_ng-1.6.1-py3-none-any.whl (29 kB)
# Collecting langchain<0.2.0,>=0.1.0 (from jupyter-ai-magics->jupyter-ai)
#   Downloading langchain-0.1.12-py3-none-any.whl (809 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->jupyter-ai) (2023.12.25)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.6->jupyter-ai) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.6->jupyter-ai) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.6->jupyter-ai) (1.2.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai<0.5.0,>=0.4.1->langchain_google_genai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai<0.5.0,>=0.4.1->langchain_google_genai) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai<0.5.0,>=0.4.1->langchain_google_genai) (4.9)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.0->jupyterlab~=4.0->jupyter-ai) (2024.2.2)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab~=4.0->jupyter-ai)
#   Downloading httpcore-1.0.4-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 4.2 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.25.0->jupyterlab~=4.0->jupyter-ai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->jupyter-server<3,>=1.6->jupyter-ai) (2.1.5)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.2,>=0.1->langchain_google_genai)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Collecting ply (from jsonpath-ng<2,>=1.5.3->jupyter-ai-magics->jupyter-ai)
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=1.6->jupyter-ai) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=1.6->jupyter-ai) (4.2.0)
# Requirement already satisfied: jsonschema[format-nongpl]>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.6->jupyter-ai) (4.19.2)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.9.0->jupyter-server<3,>=1.6->jupyter-ai)
#   Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: referencing in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.6->jupyter-ai) (0.33.0)
# Collecting rfc3339-validator (from jupyter-events>=0.9.0->jupyter-server<3,>=1.6->jupyter-ai)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.9.0->jupyter-server<3,>=1.6->jupyter-ai)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab~=4.0->jupyter-ai) (2.14.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.19.0->jupyterlab~=4.0->jupyter-ai)
#   Downloading json5-0.9.24-py3-none-any.whl (30 kB)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain<0.2.0,>=0.1.0->jupyter-ai-magics->jupyter-ai) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain<0.2.0,>=0.1.0->jupyter-ai-magics->jupyter-ai) (3.9.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.2.0,>=0.1.0->jupyter-ai-magics->jupyter-ai) (4.0.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain<0.2.0,>=0.1.0->jupyter-ai-magics->jupyter-ai)
#   Downloading dataclasses_json-0.6.4-py3-none-any.whl (28 kB)
# Collecting langchain-community<0.1,>=0.0.28 (from langchain<0.2.0,>=0.1.0->jupyter-ai-magics->jupyter-ai)
#   Downloading langchain_community-0.0.28-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 56.8 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain<0.2.0,>=0.1.0->jupyter-ai-magics->jupyter-ai)
#   Downloading langchain_text_splitters-0.0.1-py3-none-any.whl (21 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2,>=0.1->langchain_google_genai)
#   Downloading orjson-3.9.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.6->jupyter-ai) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.6->jupyter-ai) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.6->jupyter-ai) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.6->jupyter-ai) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.6->jupyter-ai) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.6->jupyter-ai) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.6->jupyter-ai) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.6->jupyter-ai) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.6->jupyter-ai) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.6->jupyter-ai) (2.16.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.6->jupyter-ai) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.2.0->jupyter-server<3,>=1.6->jupyter-ai) (2.19.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai<0.5.0,>=0.4.1->langchain_google_genai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai<0.5.0,>=0.4.1->langchain_google_genai) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-core<0.2,>=0.1->langchain_google_genai) (3.3.2)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.10/dist-packages (from terminado>=0.8.3->jupyter-server<3,>=1.6->jupyter-ai) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->jupyter-server<3,>=1.6->jupyter-ai) (21.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai<0.5.0,>=0.4.1->langchain_google_genai) (1.63.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyterlab~=4.0->jupyter-ai) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-ai-magics->jupyter-ai) (67.7.2)
# Collecting jedi>=0.16 (from ipython->jupyter-ai-magics->jupyter-ai)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 31.8 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-ai-magics->jupyter-ai) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-ai-magics->jupyter-ai) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-ai-magics->jupyter-ai) (3.0.43)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-ai-magics->jupyter-ai) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-ai-magics->jupyter-ai) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-ai-magics->jupyter-ai) (4.9.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.0->jupyter-ai-magics->jupyter-ai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.0->jupyter-ai-magics->jupyter-ai) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.0->jupyter-ai-magics->jupyter-ai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.0->jupyter-ai-magics->jupyter-ai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.0->jupyter-ai-magics->jupyter-ai) (1.9.4)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.0->jupyter-ai-magics->jupyter-ai)
#   Downloading marshmallow-3.21.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.2 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.0->jupyter-ai-magics->jupyter-ai)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai<0.5.0,>=0.4.1->langchain_google_genai) (1.62.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai<0.5.0,>=0.4.1->langchain_google_genai) (1.48.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->jupyter-ai-magics->jupyter-ai) (0.8.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.6->jupyter-ai) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.6->jupyter-ai) (0.18.0)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.6->jupyter-ai)
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.6->jupyter-ai)
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.6->jupyter-ai)
#   Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: webcolors>=1.11 in /usr/local/lib/python3.10/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.6->jupyter-ai) (1.13)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-ai-magics->jupyter-ai) (0.2.13)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.5.0,>=0.4.1->langchain_google_genai) (0.5.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=1.6->jupyter-ai) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain<0.2.0,>=0.1.0->jupyter-ai-magics->jupyter-ai) (3.0.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.6->jupyter-ai) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=1.6->jupyter-ai) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=6.4.4->jupyter-server<3,>=1.6->jupyter-ai) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.6->jupyter-ai) (2.21)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.0->jupyter-ai-magics->jupyter-ai)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.6->jupyter-ai)
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 5.9 MB/s eta 0:00:00
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.6->jupyter-ai)
#   Downloading types_python_dateutil-2.9.0.20240316-py3-none-any.whl (9.7 kB)
# Installing collected packages: ply, deepmerge, uri-template, types-python-dateutil, rfc3986-validator, rfc3339-validator, pyzmq, python-json-logger, packaging, overrides, orjson, mypy-extensions, jsonpointer, jsonpath-ng, json5, jedi, h11, fqdn, faiss-cpu, async-lru, aiosqlite, typing-inspect, tiktoken, marshmallow, jupyter-server-terminals, jupyter-client, jsonpatch, httpcore, arrow, langsmith, isoduration, httpx, dataclasses-json, langchain-core, langchain-text-splitters, langchain-community, jupyter-events, langchain, google-generativeai, langchain_google_genai, jupyter-server, jupyter-ai-magics, jupyterlab-server, jupyter-lsp, jupyterlab, jupyter-ai
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 23.2.1
#     Uninstalling pyzmq-23.2.1:
#       Successfully uninstalled pyzmq-23.2.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: google-generativeai
#     Found existing installation: google-generativeai 0.3.2
#     Uninstalling google-generativeai-0.3.2:
#       Successfully uninstalled google-generativeai-0.3.2
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.24.0
#     Uninstalling jupyter-server-1.24.0:
#       Successfully uninstalled jupyter-server-1.24.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# notebook 6.5.5 requires jupyter-client<8,>=5.3.4, but you have jupyter-client 8.6.1 which is incompatible.
# notebook 6.5.5 requires pyzmq<25,>=17, but you have pyzmq 25.1.2 which is incompatible.
# Successfully installed aiosqlite-0.20.0 arrow-1.3.0 async-lru-2.0.4 dataclasses-json-0.6.4 deepmerge-1.1.1 faiss-cpu-1.8.0 fqdn-1.5.1 google-generativeai-0.4.1 h11-0.14.0 httpcore-1.0.4 httpx-0.27.0 isoduration-20.11.0 jedi-0.19.1 json5-0.9.24 jsonpatch-1.33 jsonpath-ng-1.6.1 jsonpointer-2.4 jupyter-ai-2.12.0 jupyter-ai-magics-2.12.0 jupyter-client-8.6.1 jupyter-events-0.10.0 jupyter-lsp-2.2.4 jupyter-server-2.13.0 jupyter-server-terminals-0.5.3 jupyterlab-4.1.5 jupyterlab-server-2.25.4 langchain-0.1.12 langchain-community-0.0.28 langchain-core-0.1.32 langchain-text-splitters-0.0.1 langchain_google_genai-0.0.11 langsmith-0.1.29 marshmallow-3.21.1 mypy-extensions-1.0.0 orjson-3.9.15 overrides-7.7.0 packaging-23.2 ply-3.11 python-json-logger-2.0.7 pyzmq-25.1.2 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 tiktoken-0.6.0 types-python-dateutil-2.9.0.20240316 typing-inspect-0.9.0 uri-template-1.3.0
# Collecting langchain_nvidia_ai_endpoints
#   Downloading langchain_nvidia_ai_endpoints-0.0.4-py3-none-any.whl (33 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /usr/local/lib/python3.10/dist-packages (from langchain_nvidia_ai_endpoints) (3.9.3)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from langchain_nvidia_ai_endpoints) (0.1.32)
# Collecting pillow<11.0.0,>=10.0.0 (from langchain_nvidia_ai_endpoints)
#   Downloading pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 29.7 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.1->langchain_nvidia_ai_endpoints) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.1->langchain_nvidia_ai_endpoints) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.1->langchain_nvidia_ai_endpoints) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.1->langchain_nvidia_ai_endpoints) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.1->langchain_nvidia_ai_endpoints) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.1->langchain_nvidia_ai_endpoints) (4.0.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2.0,>=0.1.5->langchain_nvidia_ai_endpoints) (6.0.1)
# Requirement already satisfied: anyio<5,>=3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2.0,>=0.1.5->langchain_nvidia_ai_endpoints) (3.7.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2.0,>=0.1.5->langchain_nvidia_ai_endpoints) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2.0,>=0.1.5->langchain_nvidia_ai_endpoints) (0.1.29)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2.0,>=0.1.5->langchain_nvidia_ai_endpoints) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2.0,>=0.1.5->langchain_nvidia_ai_endpoints) (2.6.4)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2.0,>=0.1.5->langchain_nvidia_ai_endpoints) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2.0,>=0.1.5->langchain_nvidia_ai_endpoints) (8.2.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core<0.2.0,>=0.1.5->langchain_nvidia_ai_endpoints) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core<0.2.0,>=0.1.5->langchain_nvidia_ai_endpoints) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core<0.2.0,>=0.1.5->langchain_nvidia_ai_endpoints) (1.2.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.5->langchain_nvidia_ai_endpoints) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.5->langchain_nvidia_ai_endpoints) (3.9.15)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.5->langchain_nvidia_ai_endpoints) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.5->langchain_nvidia_ai_endpoints) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.5->langchain_nvidia_ai_endpoints) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-core<0.2.0,>=0.1.5->langchain_nvidia_ai_endpoints) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-core<0.2.0,>=0.1.5->langchain_nvidia_ai_endpoints) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-core<0.2.0,>=0.1.5->langchain_nvidia_ai_endpoints) (2024.2.2)
# Installing collected packages: pillow, langchain_nvidia_ai_endpoints
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.2.0 which is incompatible.
# Successfully installed langchain_nvidia_ai_endpoints-0.0.4 pillow-10.2.0

# %%
# %load_ext jupyter_ai

# %%
import os
from google.colab import userdata

# %%
os.environ['GOOGLE_API_KEY'] = userdata.get('GOOGLE_API_KEY')

# %%
# %ai list
# Out:
# ai21
# Requires environment variable: AI21_API_KEY (not set)
# * ai21:j1-large
# * ai21:j1-grande
# * ai21:j1-jumbo
# * ai21:j1-grande-instruct
# * ai21:j2-large
# * ai21:j2-grande
# * ai21:j2-jumbo
# * ai21:j2-grande-instruct
# * ai21:j2-jumbo-instruct
#
# bedrock
# * bedrock:amazon.titan-text-express-v1
# * bedrock:ai21.j2-ultra-v1
# * bedrock:ai21.j2-mid-v1
# * bedrock:cohere.command-light-text-v14
# * bedrock:cohere.command-text-v14
# * bedrock:meta.llama2-13b-chat-v1
# * bedrock:meta.llama2-70b-chat-v1
#
# bedrock-chat
# * bedrock-chat:anthropic.claude-v2
# * bedrock-chat:anthropic.claude-v2:1
# * bedrock-chat:anthropic.claude-instant-v1
# * bedrock-chat:anthropic.claude-3-sonnet-20240229-v1:0
#
# anthropic
# Requires environment variable: ANTHROPIC_API_KEY (not set)
# * anthropic:claude-v1
# * anthropic:claude-v1.0
# * anthropic:claude-v1.2
# * anthropic:claude-2
# * anthropic:claude-2.0
# * anthropic:claude-instant-v1
# * anthropic:claude-instant-v1.0
# * anthropic:claude-instant-v1.2
#
# anthropic-chat
# Requires environment variable: ANTHROPIC_API_KEY (not set)
# * anthropic-chat:claude-2.0
# * anthropic-chat:claude-2.1
# * anthropic-chat:claude-instant-1.2
# * anthropic-chat:claude-3-opus-20240229
# * anthropic-chat:claude-3-sonnet-20240229
#
# azure-chat-openai
# Requires environment variable: OPENAI_API_KEY (not set)
# * This provider does not define a list of models.
#
# cohere
# Requires environment variable: COHERE_API_KEY (not set)
# * cohere:command
# * cohere:command-nightly
# * cohere:command-light
# * cohere:command-light-nightly
#
# gemini
# Requires environment variable: GOOGLE_API_KEY (set)
# * gemini:gemini-1.0-pro
# * gemini:gemini-1.0-pro-001
# * gemini:gemini-1.0-pro-latest
# * gemini:gemini-1.0-pro-vision-latest
# * gemini:gemini-pro
# * gemini:gemini-pro-vision
#
# gpt4all
# * gpt4all:ggml-gpt4all-j-v1.2-jazzy
# * gpt4all:ggml-gpt4all-j-v1.3-groovy
# * gpt4all:ggml-gpt4all-l13b-snoozy
# * gpt4all:mistral-7b-openorca.Q4_0
# * gpt4all:mistral-7b-instruct-v0.1.Q4_0
# * gpt4all:gpt4all-falcon-q4_0
# * gpt4all:wizardlm-13b-v1.2.Q4_0
# * gpt4all:nous-hermes-llama2-13b.Q4_0
# * gpt4all:gpt4all-13b-snoozy-q4_0
# * gpt4all:mpt-7b-chat-merges-q4_0
# * gpt4all:orca-mini-3b-gguf2-q4_0
# * gpt4all:starcoder-q4_0
# * gpt4all:rift-coder-v0-7b-q4_0
# * gpt4all:em_german_mistral_v01.Q4_0
#
# huggingface_hub
# Requires environment variable: HUGGINGFACEHUB_API_TOKEN (not set)
# * See [https://huggingface.co/models](https://huggingface.co/models) for a list of models. Pass a model's repository ID as the model ID; for example, `huggingface_hub:ExampleOwner/example-model`.
#
# nvidia-chat
# Requires environment variable: NVIDIA_API_KEY (not set)
# * nvidia-chat:playground_llama2_70b
# * nvidia-chat:playground_nemotron_steerlm_8b
# * nvidia-chat:playground_mistral_7b
# * nvidia-chat:playground_nv_llama2_rlhf_70b
# * nvidia-chat:playground_llama2_13b
# * nvidia-chat:playground_steerlm_llama_70b
# * nvidia-chat:playground_llama2_code_13b
# * nvidia-chat:playground_yi_34b
# * nvidia-chat:playground_mixtral_8x7b
# * nvidia-chat:playground_neva_22b
# * nvidia-chat:playground_llama2_code_34b
#
# openai
# Requires environment variable: OPENAI_API_KEY (not set)
# * openai:babbage-002
# * openai:davinci-002
# * openai:gpt-3.5-turbo-instruct
#
# openai-chat
# Requires environment variable: OPENAI_API_KEY (not set)
# * openai-chat:gpt-3.5-turbo
# * openai-chat:gpt-3.5-turbo-0125
# * openai-chat:gpt-3.5-turbo-0301
# * openai-chat:gpt-3.5-turbo-0613
# * openai-chat:gpt-3.5-turbo-1106
# * openai-chat:gpt-3.5-turbo-16k
# * openai-chat:gpt-3.5-turbo-16k-0613
# * openai-chat:gpt-4
# * openai-chat:gpt-4-turbo-preview
# * openai-chat:gpt-4-0613
# * openai-chat:gpt-4-32k
# * openai-chat:gpt-4-32k-0613
# * openai-chat:gpt-4-0125-preview
# * openai-chat:gpt-4-1106-preview
#
# qianfan
# Requires environment variables: QIANFAN_AK (not set), QIANFAN_SK (not set)
# * qianfan:ERNIE-Bot
# * qianfan:ERNIE-Bot-4
#
# sagemaker-endpoint
# * Specify an endpoint name as the model ID. In addition, you must specify a region name, request schema, and response path. For more information, see the documentation about [SageMaker endpoints deployment](https://docs.aws.amazon.com/sagemaker/latest/dg/realtime-endpoints-deployment.html) and about [using magic commands with SageMaker endpoints](https://jupyter-ai.readthedocs.io/en/latest/users/index.html#using-magic-commands-with-sagemaker-endpoints).
#
# togetherai
# Requires environment variable: TOGETHER_API_KEY (not set)
# * togetherai:Austism/chronos-hermes-13b
# * togetherai:DiscoResearch/DiscoLM-mixtral-8x7b-v2
# * togetherai:EleutherAI/llemma_7b
# * togetherai:Gryphe/MythoMax-L2-13b
# * togetherai:Meta-Llama/Llama-Guard-7b
# * togetherai:Nexusflow/NexusRaven-V2-13B
# * togetherai:NousResearch/Nous-Capybara-7B-V1p9
# * togetherai:NousResearch/Nous-Hermes-2-Yi-34B
# * togetherai:NousResearch/Nous-Hermes-Llama2-13b
# * togetherai:NousResearch/Nous-Hermes-Llama2-70b
#
#
# Aliases and custom commands:
# gpt2 - huggingface_hub:gpt2
# gpt3 - openai:davinci-002
# chatgpt - openai-chat:gpt-3.5-turbo
# gpt4 - openai-chat:gpt-4
# ernie-bot - qianfan:ERNIE-Bot
# ernie-bot-4 - qianfan:ERNIE-Bot-4
# titan - bedrock:amazon.titan-tg1-large

# %%
# %%ai gemini-pro -f text
#
# Load an Earth Engine image with geemap
# Out:
# ```
# import geemap
#
# # Create a map centered at (lat, lon).
# map = geemap.Map(center=[40, -100], zoom=4)
#
# # Load an Earth Engine image.
# image = ee.Image('srtm90_v4')
#
# # Add the image to the map.
# map.addLayer(image, {'min': 0, 'max': 3000}, 'SRTM')
#
# # Display the map.
# map
# ```

# %%
import ee
import geemap

# Create a map centered at (lat, lon).
map = geemap.Map(center=[40, -100], zoom=4)

# Load an Earth Engine image.
image = ee.Image('srtm90_v4')

# Add the image to the map.
map.addLayer(image, {'min': 0, 'max': 3000}, 'SRTM')

# Display the map.
map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[40, -100], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(ch…
