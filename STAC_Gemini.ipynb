# %% [markdown]
# <a href="https://colab.research.google.com/github/milver/Experiments/blob/main/STAC_Gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install jupyter-ai langchain_google_genai
# %pip install langchain_nvidia_ai_endpoints
# Out:
# ...
#   Using cached langchain_nvidia_ai_endpoints-0.0.4-py3-none-any.whl (33 kB)
# ...
#   Using cached pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
# ...
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.2.0 which is incompatible.
# ...

# %%
# %load_ext jupyter_ai

# %%
import os
from google.colab import userdata

# %%
os.environ['GOOGLE_API_KEY'] = userdata.get('GOOGLE_API_KEY')

# %%
# %ai list
# Out:
# ai21
# Requires environment variable: AI21_API_KEY (not set)
# * ai21:j1-large
# * ai21:j1-grande
# * ai21:j1-jumbo
# * ai21:j1-grande-instruct
# * ai21:j2-large
# * ai21:j2-grande
# * ai21:j2-jumbo
# * ai21:j2-grande-instruct
# * ai21:j2-jumbo-instruct
#
# bedrock
# * bedrock:amazon.titan-text-express-v1
# * bedrock:ai21.j2-ultra-v1
# * bedrock:ai21.j2-mid-v1
# * bedrock:cohere.command-light-text-v14
# * bedrock:cohere.command-text-v14
# * bedrock:meta.llama2-13b-chat-v1
# * bedrock:meta.llama2-70b-chat-v1
#
# bedrock-chat
# * bedrock-chat:anthropic.claude-v2
# * bedrock-chat:anthropic.claude-v2:1
# * bedrock-chat:anthropic.claude-instant-v1
# * bedrock-chat:anthropic.claude-3-sonnet-20240229-v1:0
#
# anthropic
# Requires environment variable: ANTHROPIC_API_KEY (not set)
# * anthropic:claude-v1
# * anthropic:claude-v1.0
# * anthropic:claude-v1.2
# * anthropic:claude-2
# * anthropic:claude-2.0
# * anthropic:claude-instant-v1
# * anthropic:claude-instant-v1.0
# ...

# %%
# %pip install leafmap
# %pip install pystac

# %%
import leafmap
import ipywidgets
import folium
#import rioxarray
#import xarray as xr
#import leafmap.foliumap as leafmap

m = leafmap.Map(center=[39.01291503334495, -77.61583328247072], zoom = 13, basemap = "Google Maps")
#m.split_map(left_layer="TERRAIN", right_layer="OpenTopoMap")
m
# Out:
# Map(center=[39.01291503334495, -77.61583328247072], controls=(ZoomControl(options=['position', 'zoom_in_text',…

# %%
bbox1 = [m.west, m.south, m.east, m.north]
print("{}: {}".format(m.center, m.zoom))
# Out:
# [39.01291503334495, -77.61583328247072]: 13.0

# %%
from pystac_client import Client

# set pystac_client logger to DEBUG to see API calls
# import logging
# logging.basicConfig()
# logger = logging.getLogger('pystac_client')
# logger.setLevel(logging.DEBUG)

# %%
# STAC API root URL
URL = 'https://planetarycomputer.microsoft.com/api/stac/v1'

# custom headers
headers = []

cat = Client.open(URL, headers=headers)
cat
# Out:
# <Client id=microsoft-pc>

# %%
# prompt: I want a drop-down box that has a list of all of the collections in the catalog. Once a collection has been selected, assign the collection id to a variable called MyCollection

import ipywidgets as widgets

# Get a list of all collections in the catalog
collections = cat.get_collections()

# Create a dropdown widget
dropdown = widgets.Dropdown(
    options=[c.id for c in collections],
    description='Collection:',
    disabled=False,
)

# Display the dropdown widget
display(dropdown)

# Define a function to handle the selection event
def on_change(change):
    global MyCollection
    MyCollection = change['new']

# Register the function to be called when the selection changes
dropdown.observe(on_change, names='value')
# Out:
# Dropdown(description='Collection:', options=('daymet-annual-pr', 'daymet-daily-hi', '3dep-seamless', '3dep-lid…

# %%
# limit sets the # of items per page so we can see multiple pages getting fetched
search = cat.search(
    max_items = 50,
    collections = MyCollection,
    #intersects = geom,
    bbox = bbox1,
    #datetime = "2015-01-01/2024-03-31",
)
# retrieve the items as dictionaries, rather than Item objects
items = list(search.items_as_dicts())
len(items)
# Out:
# 9

# %%
for item in search.items():
    print(f"- {item.id}")
# Out:
# - USGS_LPC_VA_Fairfax_County_2018-dtm-2m-1-1
# - USGS_LPC_VA_Fairfax_County_2018-dtm-2m-1-0
# - USGS_LPC_VA_Fairfax_County_2018-dtm-2m-0-1
# - VA_LoudounCo_2012-dtm-2m-4-4
# - VA_LoudounCo_2012-dtm-2m-4-3
# - VA_LoudounCo_2012-dtm-2m-3-4
# - VA_LoudounCo_2012-dtm-2m-3-3
# - VA_LoudounCo_2012-dtm-2m-2-4
# - VA_LoudounCo_2012-dtm-2m-2-3

# %%
# prompt: create an ipytree object using the item.ids as nodes and the assets underneath the node, as nodes themselves.

import ipytree
from ipytree import Tree, Node

tree = ipytree.Tree()
parent_of = {}

# Iterate over the items
for item in search.items():
    # Create a node for the item
    item_node = Node(name=item.id)

    # Iterate over the assets in the item
    for key, value in item.assets.items():
        # Create a node for the asset
        asset_node = Node(name=key)
        asset_node2 = Node(name=value.href)
        parent_of[value.href]=item_node.name
        asset_node2.opened = False
        asset_node.add_node(asset_node2)
        asset_node.opened = False
        # Add the asset node to the item node
        item_node.add_node(asset_node)
    # Add the node to the tree
    item_node.opened = False
    tree.add_node(item_node)

# Display the tree
tree
# Out:
# Tree(nodes=(Node(name='USGS_LPC_VA_Fairfax_County_2018-dtm-2m-1-1', nodes=(Node(name='data', nodes=(Node(name=…

# %%
# prompt: for the selected root nodes in the previous tree output, I want to add the data values to the leafmap instance

import leafmap
m = leafmap.Map(center=[39.04446940931973, -77.45992183685304], zoom = 16, basemap = "Google Maps")


#def add_stac_data_to_map(tree):
selected_nodes = tree.selected_nodes
for node in selected_nodes:
  #print(node.name)
  #print(parent_of[node.name])

  url = node.name
  leafmap.cog_bounds(url)
  #leafmap.cog_center(url)
  #leafmap.cog_bands(url)
  #leafmap.cog_tile(url)
  #m.add_cog_layer(url= node.name, name= parent_of[node.name], attribution = "MPC", bands= 0)
  m.add_stac_layer(name=parent_of[node.name], collection= MyCollection, item=parent_of[node.name], assets= "data", titile_endpoint= "tilejson")
m



  #m.add_cog_layer(url= node.name, name= )
#m

#       collection = node.name
#       # Get a list of all assets in the collection
#       assets = cat.get_collection(collection).assets
#       # Iterate over the assets
#       for asset in assets.values():
#         # Check if the asset is a GeoTIFF
#         if asset.media_type == 'image/tiff; application=geotiff; profile=cloud-optimized':
#           # Add the asset to the map
#           m.add_stac(collection, asset=asset.href)

# # Add the data values to the leafmap instance
# add_stac_data_to_map(tree)
# Out:
# Map(center=[39.04446940931973, -77.45992183685304], controls=(ZoomControl(options=['position', 'zoom_in_text',…

# %%
# !pip install ipytree

# %%
# prompt: modify the previous cell code to print the item id and the respective asset key values, like "thumbnail"

# Print the item ID and the respective asset key values
for item in search.items():
    print(f"{item.id}:")
    for key, value in item.assets.items():
        print(f"  {key}: {value}")

# %%
# prompt: add the tilejson assets to the leafmap and display them. Alert when the assets are loaded.

import leafmap
m = leafmap.Map(center=[39.04446940931973, -77.45992183685304], zoom = 16, basemap = "Google Maps")

m.add_cog_layer()

# Get the tilejson asset from the first item in the search results
#tilejson_asset = items[1]['assets']['tilejson']

# Add the tilejson asset to the map

#m.add_tile_layer(tilejson_asset['href'], name='dem1', attribution='Microsoft Planetary Computer')
#m.add_stac_layer(
    #url= tilejson_asset['href'],
    #collection= MyCollection,
    #item='VA_LoudounCo_2012-dtm-2m-5-4',
    #assets= tilejson_asset['href'],
    #assets= items[1]['assets'],
    #name='Tile1',
    #attribution='Microsoft Planetary Computer')

# Display the map
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[39.04446940931973, -77.45992183685304], controls=(ZoomControl(options=['position', 'zoom_in_text',…

# %%
# PROJECT = 'ee-my-milver'
# !gcloud auth login --project {PROJECT}
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Go to the following link in your browser:
#
# ...

# %%
# prompt: Create a geemap instance and add the tilejson_asset that was referenced in the previous cell, to the map
import ee
import geemap

ee.Authenticate()
ee.Initialize(project = 'ee-my-milver')

# Create a geemap instance
map = geemap.Map()

# Add the tilejson asset to the map
map.add_tile_layer(tilejson_asset['href'], name='dem1', attribution='Microsoft Planetary Computer')

map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %%
# %%ai gemini-pro -f text
#
# For the ipytree object, explain how to query the parent of a node
# Out:
# To query the parent of a node in an ipytree object, use the `parent` attribute. For example:
#
# ```
# import ipytree
# tree = ipytree.Tree()
#
# node = tree.add_node('foo')
# parent = node.parent  # The parent of 'foo'
# ```

# %%
import ee
import geemap

# Create a map centered at (lat, lon).
map = geemap.Map(center=[40, -100], zoom=4)

# Load an Earth Engine image.
image = ee.Image('srtm90_v4')

# Add the image to the map.
map.addLayer(image, {'min': 0, 'max': 3000}, 'SRTM')

# Display the map.
map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[40, -100], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(ch…
